# %%
import pandas as pd

#define files
cy_2020 = "202005-citibike-tripdata.csv"
# cy_2021 = "202105-citibike-tripdata.csv"

# %%
#make pdframes
cy_may20_df = pd.read_csv(cy_2020)
# cy_may21_df = pd.read_csv(cy_2021)

# %%
cy_may20_df.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           336  2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 1           853  2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 2            78  2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 3          1185  2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 4           272  2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
#
#    start station id                  start station name  \
# 0              2017                     E 43 St & 2 Ave
# 1              3376                     E 65 St & 2 Ave
# 2               396          Lefferts Pl & Franklin Ave
# 3              3630  Frederick Douglass Blvd & W 115 St
# 4              3776          Central Ave & Starr Street
#
#    start station latitude  start station longitude  end station id  \
# 0               40.750224               -73.971214             465
# 1               40.764719               -73.962221             478
# ...

# %%
#may 2021
cy_2021 = "202105-citibike-tripdata.csv"
cy_may21_df = pd.read_csv(cy_2021)
# Out:
# C:\Users\Julio\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
cy_may21_df.head(5)
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E12103A91226099A   docked_bike  2021-05-06 17:25:01  2021-05-06 17:45:25
# 1  26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08  2021-05-13 13:07:37
# 2  A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13  2021-05-16 08:45:47
# 3  43E79A45997B7390   docked_bike  2021-05-01 08:38:14  2021-05-01 08:54:27
# 4  8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31  2021-05-09 08:27:05
#
#    start_station_name start_station_id        end_station_name end_station_id  \
# 0  Broadway & W 60 St          6948.11         1 Ave & E 78 St        7020.09
# 1  Broadway & W 25 St          6173.08       E 2 St & Avenue B        5515.02
# 2       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
# 3       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
# 4       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
#
# ...

# %%
start_stop_0520_group = cy_may20_df.groupby(["start station name","end station name","end station latitude","end station longitude"])
start_stop_0520_group.count().head(10)
# Out:
#                                                                                                      tripduration  \
# start station name end station name                      end station latitude end station longitude
# 1 Ave & E 110 St   1 Ave & E 110 St                      40.792327            -73.938300                      200
#                    1 Ave & E 18 St [temporarily removed] 40.733812            -73.980544                        1
#                    1 Ave & E 5 St                        40.725864            -73.986389                        1
#                    1 Ave & E 62 St                       40.761227            -73.960940                        8
#                    1 Ave & E 68 St                       40.765005            -73.958185                       11
#                    1 Ave & E 78 St                       40.771404            -73.953517                        8
# ...

# %%
start_stop_0520_pos = cy_may20_df.groupby(["start station name","start station latitude","start station longitude"])
start_stop_0520_pos['start station name'].count().head(10)
# Out:
# start station name                     start station latitude  start station longitude
# 1 Ave & E 110 St                       40.792327               -73.938300                 1342
# 1 Ave & E 16 St [temporarily removed]  40.732219               -73.981656                 4434
# 1 Ave & E 18 St [temporarily removed]  40.733812               -73.980544                 4388
# 1 Ave & E 30 St                        40.741444               -73.975361                 3274
# 1 Ave & E 44 St                        40.750020               -73.969053                 2759
# 1 Ave & E 5 St                         40.725864               -73.986389                 2761
# 1 Ave & E 62 St                        40.761227               -73.960940                 4723
# 1 Ave & E 68 St                        40.765005               -73.958185                 8007
# 1 Ave & E 78 St                        40.771404               -73.953517                 4730
# ...

# %%
start_stop_0520_pos["start station name"].head(10)
# Out:
# 0                             E 43 St & 2 Ave
# 1                             E 65 St & 2 Ave
# 2                  Lefferts Pl & Franklin Ave
# 3          Frederick Douglass Blvd & W 115 St
# 4                  Central Ave & Starr Street
#                           ...
# 1440172              St. Ann's Ave & E 144 St
# 1443138              St. Ann's Ave & E 144 St
# 1458351              St. Ann's Ave & E 144 St
# 1473934              St. Ann's Ave & E 144 St
# 1474033              St. Ann's Ave & E 144 St
# Name: start station name, Length: 9240, dtype: object

# %%
start_summary_df = pd.DataFrame(start_stop_0520_pos.count())

# %%
start_summary_df.head()
# Out:
#                                                                                       tripduration  \
# start station name                    start station latitude start station longitude
# 1 Ave & E 110 St                      40.792327              -73.938300                       1342
# 1 Ave & E 16 St [temporarily removed] 40.732219              -73.981656                       4434
# 1 Ave & E 18 St [temporarily removed] 40.733812              -73.980544                       4388
# 1 Ave & E 30 St                       40.741444              -73.975361                       3274
# 1 Ave & E 44 St                       40.750020              -73.969053                       2759
#
#                                                                                       starttime  \
# start station name                    start station latitude start station longitude
# 1 Ave & E 110 St                      40.792327              -73.938300                    1342
# ...

# %%
start_summary_df.to_csv('start_summary.csv')

# %%
start_end_summary_df = pd.DataFrame(start_stop_0520_group.count())

# %%
start_end_summary_df.to_csv('start_end_summary_2020.csv')

# %%
start_stop_0521_pos = cy_may21_df.groupby(["start_station_name","start_lat","start_lng"])
start_stop_0521_pos.count().head(10)
# Out:
#                                          ride_id  rideable_type  started_at  \
# start_station_name start_lat start_lng
# 1 Ave & E 110 St   40.792327 -73.938300     2035           2035        2035
# 1 Ave & E 16 St    40.732218 -73.981655     7126           7126        7126
#                    40.732219 -73.981656       40             40          40
# 1 Ave & E 18 St    40.733812 -73.980544     6006           6006        6006
# 1 Ave & E 30 St    40.741443 -73.975360     5023           5023        5023
#                    40.741444 -73.975361       33             33          33
# 1 Ave & E 39 St    40.747140 -73.971130     7136           7136        7136
# 1 Ave & E 44 St    40.750019 -73.969053     2810           2810        2810
#                    40.750020 -73.969053       42             42          42
# 1 Ave & E 6 St     40.726330 -73.986168     5686           5686        5686
#
#                                          ended_at  start_station_id  \
# ...

# %%
start_summary21_df = pd.DataFrame(start_stop_0521_pos.count())
# start_summary21_df.head(10)
start_summary21_df.to_csv('start_summary_may2021.csv')

# %%
start_stop_0521_group = cy_may21_df.groupby(["start_station_name","end_station_name","end_lat","end_lng"])
# start_stop_0521_group.count().head(10)
start_end_summary21_df = pd.DataFrame(start_stop_0521_group.count())
start_end_summary21_df.to_csv('start_end_summary_may2021.csv')
